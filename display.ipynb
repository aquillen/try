# %%
# %matplotlib nbagg
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation

window = 100000

### Set up 3D window using matplotlib
fig = plt.figure()
ax = p3.Axes3D(fig)

### Set axis labels and ranges
ax.set_xlim3d([-window/2, window/2])
ax.set_xlabel('X')

ax.set_ylim3d([-window/2, window/2])
ax.set_ylabel('Y')

ax.set_zlim3d([-window/2, window/2])
ax.set_zlabel('Z')

ax.set_title('Pan')

### Create Pan
x = [0,1]
y = [0,-1]
z = [0,6000]

ax.scatter(x,y,z)


### function to run between each frame of the animation
#update = 

#ani = animation(fig,update)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D  
# Axes3D import has side effects, it enables using projection='3d' in add_subplot
import matplotlib.pyplot as plt
import random

def fun(x, y):
    return x**2 + y

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = y = np.arange(-3.0, 3.0, 0.05)
X, Y = np.meshgrid(x, y)
zs = np.array(fun(np.ravel(X), np.ravel(Y)))
Z = zs.reshape(X.shape)

ax.plot_surface(X, Y, Z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
Z
# Out:
# array([[ 6.    ,  5.7025,  5.41  , ...,  5.1225,  5.41  ,  5.7025],
#        [ 6.05  ,  5.7525,  5.46  , ...,  5.1725,  5.46  ,  5.7525],
#        [ 6.1   ,  5.8025,  5.51  , ...,  5.2225,  5.51  ,  5.8025],
#        ...,
#        [11.85  , 11.5525, 11.26  , ..., 10.9725, 11.26  , 11.5525],
#        [11.9   , 11.6025, 11.31  , ..., 11.0225, 11.31  , 11.6025],
#        [11.95  , 11.6525, 11.36  , ..., 11.0725, 11.36  , 11.6525]])
