# %%
# %matplotlib
import numpy as np

# %matplotlib inline
# Out:
# Using matplotlib backend: Qt5Agg

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()

# %%
x = np.arange(0,10,0.1)
y= x**2
plt.plot(x,y)

# %%
import sub

# %%
z = sub.myfunc(x)

# %%
plt.plot(x,z)

# %%
sub.myfunc(0)
